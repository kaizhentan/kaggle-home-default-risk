# %%
import numpy as np 
import pandas as pd

# %%
df_app_test=pd.read_csv('application_test.csv').set_index('SK_ID_CURR')
df_app_train=pd.read_csv('application_train.csv').set_index('SK_ID_CURR')
df_bureau=pd.read_csv('bureau.csv').sort_values('SK_ID_CURR').set_index('SK_ID_CURR')
df_bureau_balance=pd.read_csv('bureau_balance.csv').set_index('SK_ID_BUREAU')
df_creidit_balance=pd.read_csv('credit_card_balance.csv').sort_values('SK_ID_CURR').set_index('SK_ID_CURR')

# %%
df_credit=pd.read_csv('HomeCredit_columns_description.csv',encoding = 'unicode_escape').drop('Unnamed: 0',axis=1)

# %%
df_install=pd.read_csv('installments_payments.csv')

# %%
df_app_test.columns.tolist()
# Out:
# ['NAME_CONTRACT_TYPE',
#  'CODE_GENDER',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'NAME_TYPE_SUITE',
#  'NAME_INCOME_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'NAME_HOUSING_TYPE',
#  'REGION_POPULATION_RELATIVE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'DAYS_REGISTRATION',
#  'DAYS_ID_PUBLISH',
#  'OWN_CAR_AGE',
#  'FLAG_MOBIL',
#  'FLAG_EMP_PHONE',
#  'FLAG_WORK_PHONE',
#  'FLAG_CONT_MOBILE',
#  'FLAG_PHONE',
#  'FLAG_EMAIL',
#  'OCCUPATION_TYPE',
#  'CNT_FAM_MEMBERS',
#  'REGION_RATING_CLIENT',
#  'REGION_RATING_CLIENT_W_CITY',
#  'WEEKDAY_APPR_PROCESS_START',
#  'HOUR_APPR_PROCESS_START',
#  'REG_REGION_NOT_LIVE_REGION',
#  'REG_REGION_NOT_WORK_REGION',
#  'LIVE_REGION_NOT_WORK_REGION',
#  'REG_CITY_NOT_LIVE_CITY',
#  'REG_CITY_NOT_WORK_CITY',
#  'LIVE_CITY_NOT_WORK_CITY',
#  'ORGANIZATION_TYPE',
#  'EXT_SOURCE_1',
#  'EXT_SOURCE_2',
#  'EXT_SOURCE_3',
# ...

# %%
set(df_app_train['NAME_CONTRACT_TYPE'])
# Out:
# {'Cash loans', 'Revolving loans'}

# %%
df_app_train.columns.tolist()
# Out:
# ['TARGET',
#  'NAME_CONTRACT_TYPE',
#  'CODE_GENDER',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'NAME_TYPE_SUITE',
#  'NAME_INCOME_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'NAME_HOUSING_TYPE',
#  'REGION_POPULATION_RELATIVE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'DAYS_REGISTRATION',
#  'DAYS_ID_PUBLISH',
#  'OWN_CAR_AGE',
#  'FLAG_MOBIL',
#  'FLAG_EMP_PHONE',
#  'FLAG_WORK_PHONE',
#  'FLAG_CONT_MOBILE',
#  'FLAG_PHONE',
#  'FLAG_EMAIL',
#  'OCCUPATION_TYPE',
#  'CNT_FAM_MEMBERS',
#  'REGION_RATING_CLIENT',
#  'REGION_RATING_CLIENT_W_CITY',
#  'WEEKDAY_APPR_PROCESS_START',
#  'HOUR_APPR_PROCESS_START',
#  'REG_REGION_NOT_LIVE_REGION',
#  'REG_REGION_NOT_WORK_REGION',
#  'LIVE_REGION_NOT_WORK_REGION',
#  'REG_CITY_NOT_LIVE_CITY',
#  'REG_CITY_NOT_WORK_CITY',
#  'LIVE_CITY_NOT_WORK_CITY',
#  'ORGANIZATION_TYPE',
#  'EXT_SOURCE_1',
#  'EXT_SOURCE_2',
# ...

# %%
df_app_train[df_app_train['CODE_GENDER']=='XNA']
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 141289           0    Revolving loans         XNA            Y
# 144669           0    Revolving loans         XNA            N
# 196708           0    Revolving loans         XNA            N
# 319880           0    Revolving loans         XNA            Y
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 141289                   Y             0          207000.0    382500.0
# 144669                   Y             2          157500.0    270000.0
# 196708                   Y             1          135000.0    405000.0
# 319880                   Y             0          247500.0    540000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE             ...              \
# SK_ID_CURR                                           ...
# 141289          19125.0         337500.0             ...
# 144669          13500.0         225000.0             ...
# ...
